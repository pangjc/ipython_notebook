# %%
# version 0 works for the MIT experimental set up

print(__doc__)

import csv
import numpy as np
from numpy import genfromtxt
from sklearn import svm, metrics
import pickle
import matplotlib.pyplot as plt
import pandas as pd

featureFileFullName = 'JD_Cam2_20150514Cages1_2_features_predicted.csv'

df = pd.read_csv(featureFileFullName,header = True)
df.head(10)
# Out:
# Automatically created module for IPython interactive environment
#    Unnamed: 0  iframe  Hu1[0][0]  Hu1[1][0]  Hu1[2][0]  Hu1[3][0]  Hu1[4][0]  \
# 0           0    6083  -1.872643  -3.984518  -5.370896  -5.308648 -10.648769
# 1           1    6084  -2.067252  -4.259270  -7.007375  -7.073670 -14.114987
# 2           2    6085  -2.110542  -4.344296  -7.170787  -7.234158 -14.437675
# 3           3    6086  -2.241608  -4.582128  -7.746588  -8.072604 -15.982489
# 4           4    6087  -2.267681  -4.638537  -7.803314  -8.168664 -16.156006
# 5           5    6088  -2.317116  -4.747030  -7.821697  -8.172258 -16.170259
# 6           6    6089  -2.399063  -4.947798  -7.837165  -8.224599 -16.260517
# 7           7    6090  -2.423599  -5.007857  -7.907737  -8.364753 -16.515006
# 8           8    6091  -2.501493  -5.188709  -8.095389  -8.857078 -17.592248
# 9           9    6092  -2.525205  -5.268085  -8.023750  -8.980648  17.531074
#
#    Hu1[5][0]  Hu1[6][0]  Hu2[0][0]   ...     corner3  corner4  height  width  \
# 0  -7.309002  12.045215  -0.343056   ...         514      386      47    129
# 1  -9.205149  15.332941  -0.683421   ...         514      383      47    132
# 2  -9.406776  15.596001  -0.962007   ...         514      382      48    133
# 3 -10.383941 -17.420005  -1.087388   ...         515      382      60    134
# 4 -10.518723 -17.258197  -1.247444   ...         515      381      63    135
# 5 -10.575798 -17.333300  -1.391171   ...         515      381      67    135
# 6 -10.757934 -17.075331  -1.430521   ...         516      380      78    137
# 7 -10.963119 -17.103161  -1.550832   ...         516      380      82    137
# 8 -12.116917 -17.411845  -1.614519   ...         516      380      93    137
# 9  11.674941 -17.833247  -1.696671   ...         516      379     141    138
#
#      extend  JD_score  SMO_score  JD_score_group  SMO_score_group  predict
# 0  0.050305         0          0               0                0        0
# 1  0.109768         0          0               0                0        0
# 2  0.118421         0          0               0                0        0
# 3  0.158582         0          0               0                0        0
# 4  0.159200         0          0               0                0        0
# 5  0.164842         0          0               0                0        0
# 6  0.172001         0          0               0                0        0
# 7  0.175093         0          0               0                0        0
# 8  0.186563         0          0               0                0        0
# 9  0.135780         0          0               0                0        0
#
# [10 rows x 33 columns]

# %%
nrow,ncol = df.shape

activitiesNames = ['0','1-3','4-6']


ts = np.linspace(0,(nrow-1)/900.0,nrow)
print len(ts), len(df['predict'])

#140,602,2678

ind = range(140*15,140*15+15*60)
            
plt.subplot(311)
plt.plot(ts[ind],df['predict'][ind],'r',linewidth = 3.0,label = "COM")
plt.plot(ts[ind],df['JD_score_group'][ind],'b',linewidth = 1.0,label = "JD")
plt.plot(ts[ind],df['SMO_score_group'][ind],'k',linewidth = 1.0,label = "SMO")
plt.grid()
plt.ylim(-0.5,2.5)
plt.xlim(ts[ind[0]],ts[ind[-1]])
plt.xlabel('Time (minutes)',fontsize = 20)
plt.ylabel('Seizure stages',fontsize = 20)
tick_marks = np.arange(len(activitiesNames))
plt.yticks(tick_marks, activitiesNames,fontsize=15)
plt.legend(bbox_to_anchor=(.90, 0.90), loc=2, borderaxespad=0.1)
plt.title('Case 1')

ind = range(602*15,602*15+15*60)
            
plt.subplot(312)
plt.plot(ts[ind],df['predict'][ind],'r',linewidth = 3.0,label = "COM")
plt.plot(ts[ind],df['JD_score_group'][ind],'b',linewidth = 1.0,label = "JD")
plt.plot(ts[ind],df['SMO_score_group'][ind],'k',linewidth = 1.0,label = "SMO")
plt.grid()
plt.ylim(-0.5,2.5)
plt.xlim(ts[ind[0]],ts[ind[-1]])
plt.xlabel('Time (minutes)',fontsize = 20)
plt.ylabel('Seizure stages',fontsize = 20)
tick_marks = np.arange(len(activitiesNames))
plt.yticks(tick_marks, activitiesNames,fontsize=15)
plt.legend(bbox_to_anchor=(.90, 0.90), loc=2, borderaxespad=0.1)
plt.title('Case 2')

ind = range(2678*15,2678*15+15*60)
            
plt.subplot(313)
plt.plot(ts[ind],df['predict'][ind],'r',linewidth = 3.0,label = "COM")
plt.plot(ts[ind],df['JD_score_group'][ind],'b',linewidth = 1.0,label = "JD")
plt.plot(ts[ind],df['SMO_score_group'][ind],'k',linewidth = 1.0,label = "SMO")
plt.grid()
plt.ylim(-0.5,2.5)
plt.xlim(ts[ind[0]],ts[ind[-1]])
plt.xlabel('Time (minutes)',fontsize = 20)
plt.ylabel('Seizure stages',fontsize = 20)
tick_marks = np.arange(len(activitiesNames))
plt.yticks(tick_marks, activitiesNames,fontsize=15)
plt.legend(bbox_to_anchor=(.90, 0.90), loc=2, borderaxespad=0.1)
plt.title('Case 3')

plt.show()
#df.to_csv(featureFileFullNameSave)
print ts[-1]
# Out:
# 47873 47873
# 53.1911111111
